# %% [markdown]
# # Dataset class

# %%
import numpy as np

class Dataset:
    def __init__(self, size, bn, missingness_class):
        self.size = size
        self.num_variables = num_variables
        self.bn = bn
        self.data = self.generate_data(bn)
        assert missingness_class in ["complete", "MAR", "MACR"]
        self.missingness_class = missingness_class
        self.delete_data()
    
    def generate_data(self, random_seed):
        pass

    def delete_data(self):
        if self.missingness_class == "complete":
            pass
        elif self.missingness_class == "MCAR":
            pass
        else:  # self.missingness_class == "MAR"
            pass
    
    def generate_missingness_graph(self):
        if self.missingness_class == "complete":
            pass
        elif self.missingness_class == "MCAR":
            pass
        else:  # self.missingness_class == "MAR"
            pass
    
# Example usage
size = 100
num_variables = 5
data = np.random.rand(size, num_variables)

complete_dataset = CompleteDataset(size, num_variables, data.copy())
mar_dataset = MAR_Dataset(size, num_variables, data.copy())
mcar_dataset = MCAR_Dataset(size, num_variables, data.copy())

complete_dataset.delete_data()
mar_dataset.delete_data()
mcar_dataset.delete_data()

print("Complete Dataset:\n", complete_dataset.data)
print("MAR Dataset:\n", mar_dataset.data)
print("MCAR Dataset:\n", mcar_dataset.data)

# %% [markdown]
# # Algo class

# %%
class Learner:
    def __init__(self, dataset):
        self.dataset = dataset

    def estimate(variables):
        '''
        args:
        - variables: A list of variables whose marginal distribution is calculated

        Calculate the marginal distribution P(variables)
        '''
        pass

class DMCAR(Learner):
    def __init__(self, dataset):
        assert dataset.missingness_class == "MCAR"
        super().__init__(dataset)

    def estimate(variables):
        '''
        args:
        - variables: A list of variables whose marginal distribution is calculated

        Calculate the marginal distribution P(variables)
        '''
        pass

class FMCAR(Learner):
    def __init__(self, dataset):
        assert dataset.missingness_class == "MCAR"
        super().__init__(dataset)

    def estimate(variables):
        '''
        args:
        - variables: A list of variables whose marginal distribution is calculated

        Calculate the marginal distribution P(variables)
        '''
        pass

class DMAR(Learner):
    def __init__(self, dataset):
        assert dataset.missingness_class == "MAR"
        super().__init__(dataset)

    def estimate(variables):
        '''
        args:
        - variables: A list of variables whose marginal distribution is calculated

        Calculate the marginal distribution P(variables)
        '''
        pass

class FMAR(Learner):
    def __init__(self, dataset):
        assert dataset.missingness_class == "MAR"
        super().__init__(dataset)

    def estimate(variables):
        '''
        args:
        - variables: A list of variables whose marginal distribution is calculated

        Calculate the marginal distribution P(variables)
        '''
        pass

class IDMAR(Learner):
    def __init__(self, dataset):
        assert dataset.missingness_class == "MAR"
        super().__init__(dataset)

    def estimate(variables):
        '''
        args:
        - variables: A list of variables whose marginal distribution is calculated

        Calculate the marginal distribution P(variables)
        '''
        pass

class IFMAR(Learner):
    def __init__(self, dataset):
        assert dataset.missingness_class == "MAR"
        super().__init__(dataset)

    def estimate(variables):
        '''
        args:
        - variables: A list of variables whose marginal distribution is calculated

        Calculate the marginal distribution P(variables)
        '''
        pass

# %% [markdown]
# # Experiment

# %%
# Creating the
from pgmpy.models import DiscreteBayesianNetwork
bayes_net = DiscreteBayesianNetwork()
